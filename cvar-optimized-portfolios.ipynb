# %% [markdown]
# <a href="https://colab.research.google.com/github/kristenlowe/cvar-optimized-portfolios/blob/main/cvar-optimized-portfolios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Part 1: load stock data and calculate daily percentage returns

# %%
# Import libraries
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB

# Load stock data
df2019 = pd.read_csv("stocks2019.csv")
df2020 = pd.read_csv("stocks2020.csv")

# View first few rows of stocks
df2019.head()
# Out:
#             X          NDX       ATVI        ADBE        AMD        ALXN  \
# 0  2019-01-02  6360.870117  46.350380  224.570007  18.830000   98.050003
# 1  2019-01-03  6147.129883  44.704514  215.699997  17.049999  100.209999
# 2  2019-01-04  6422.669922  46.488358  226.190002  19.000000  106.000000
# 3  2019-01-07  6488.250000  47.799141  229.259995  20.570000  107.940002
# 4  2019-01-08  6551.850098  49.247898  232.679993  20.750000  108.610001
#
#          ALGN        GOOGL         GOOG         AMZN  ...       TCOM  \
# 0  202.119995  1054.680054  1045.849976  1539.130005  ...  27.590000
# 1  184.779999  1025.469971  1016.059998  1500.280029  ...  26.959999
# 2  186.710007  1078.069946  1070.709961  1575.390015  ...  28.549999
# 3  189.919998  1075.920044  1068.390015  1629.510010  ...  29.180000
# 4  192.949997  1085.369995  1076.280029  1656.579956  ...  29.480000
#
#          ULTA        VRSN        VRSK        VRTX        WBA        WDAY  \
# 0  247.970001  147.759995  107.364159  164.080002  63.920757  159.740005
# 1  243.360001  142.589996  104.083450  163.729996  63.253742  154.020004
# 2  255.029999  148.970001  108.678413  172.699997  65.358139  163.350006
# 3  271.000000  151.399994  108.787117  175.850006  65.733910  163.500000
# 4  276.000000  156.919998  109.755516  178.190002  67.049149  166.949997
#
#          WDC        XEL       XLNX
# 0  36.312473  46.041862  84.600266
# 1  33.835327  45.860447  81.414970
# 2  35.268467  46.309223  85.184715
# 3  36.521275  46.108707  87.434891
# 4  36.170105  46.643410  85.769180
#
# [5 rows x 102 columns]

# %%
# Set date column as index
df2019.set_index(df2019.columns[0], inplace=True)
df2020.set_index(df2020.columns[0], inplace=True)

# Convert prices to daily returns
ret2019 = df2019.pct_change()
ret2020 = df2020.pct_change()

# View first few rows of returns
ret2019.head()
# Out:
#                  NDX      ATVI      ADBE       AMD      ALXN      ALGN  \
# X
# 2019-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-01-03 -0.033602 -0.035509 -0.039498 -0.094530  0.022030 -0.085791
# 2019-01-04  0.044824  0.039903  0.048632  0.114370  0.057779  0.010445
# 2019-01-07  0.010211  0.028196  0.013573  0.082632  0.018302  0.017192
# 2019-01-08  0.009802  0.030309  0.014918  0.008751  0.006207  0.015954
#
#                GOOGL      GOOG      AMZN      AMGN  ...      TCOM      ULTA  \
# X                                                   ...
# 2019-01-02       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2019-01-03 -0.027696 -0.028484 -0.025242 -0.015216  ... -0.022834 -0.018591
# 2019-01-04  0.051294  0.053786  0.050064  0.034184  ...  0.058976  0.047954
# 2019-01-07 -0.001994 -0.002167  0.034353  0.013457  ...  0.022067  0.062620
# 2019-01-08  0.008783  0.007385  0.016612  0.012824  ...  0.010281  0.018450
#
#                 VRSN      VRSK      VRTX       WBA      WDAY       WDC  \
# X
# 2019-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-01-03 -0.034989 -0.030557 -0.002133 -0.010435 -0.035808 -0.068217
# 2019-01-04  0.044744  0.044147  0.054785  0.033269  0.060577  0.042356
# 2019-01-07  0.016312  0.001000  0.018240  0.005749  0.000918  0.035522
# 2019-01-08  0.036460  0.008902  0.013307  0.020009  0.021101 -0.009615
#
#                  XEL      XLNX
# X
# 2019-01-02       NaN       NaN
# 2019-01-03 -0.003940 -0.037651
# 2019-01-04  0.009786  0.046303
# 2019-01-07 -0.004330  0.026415
# 2019-01-08  0.011597 -0.019051
#
# [5 rows x 101 columns]

# %%
# Remove NDX column
stocks2019 = ret2019.drop(columns=["NDX"])
stocks2020 = ret2020.drop(columns=["NDX"])

# %%
stocks2019.head()
# Out:
#                 ATVI      ADBE       AMD      ALXN      ALGN     GOOGL  \
# X
# 2019-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-01-03 -0.035509 -0.039498 -0.094530  0.022030 -0.085791 -0.027696
# 2019-01-04  0.039903  0.048632  0.114370  0.057779  0.010445  0.051294
# 2019-01-07  0.028196  0.013573  0.082632  0.018302  0.017192 -0.001994
# 2019-01-08  0.030309  0.014918  0.008751  0.006207  0.015954  0.008783
#
#                 GOOG      AMZN      AMGN       ADI  ...      TCOM      ULTA  \
# X                                                   ...
# 2019-01-02       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2019-01-03 -0.028484 -0.025242 -0.015216 -0.060405  ... -0.022834 -0.018591
# 2019-01-04  0.053786  0.050064  0.034184  0.024278  ...  0.058976  0.047954
# 2019-01-07 -0.002167  0.034353  0.013457  0.006288  ...  0.022067  0.062620
# 2019-01-08  0.007385  0.016612  0.012824  0.024396  ...  0.010281  0.018450
#
#                 VRSN      VRSK      VRTX       WBA      WDAY       WDC  \
# X
# 2019-01-02       NaN       NaN       NaN       NaN       NaN       NaN
# 2019-01-03 -0.034989 -0.030557 -0.002133 -0.010435 -0.035808 -0.068217
# 2019-01-04  0.044744  0.044147  0.054785  0.033269  0.060577  0.042356
# 2019-01-07  0.016312  0.001000  0.018240  0.005749  0.000918  0.035522
# 2019-01-08  0.036460  0.008902  0.013307  0.020009  0.021101 -0.009615
#
#                  XEL      XLNX
# X
# 2019-01-02       NaN       NaN
# 2019-01-03 -0.003940 -0.037651
# 2019-01-04  0.009786  0.046303
# 2019-01-07 -0.004330  0.026415
# 2019-01-08  0.011597 -0.019051
#
# [5 rows x 100 columns]

# %%
stocks2020.head()
# Out:
#                 ATVI      ADBE       AMD      ALXN      ALGN     GOOGL  \
# Unnamed: 0
# 1/2/20           NaN       NaN       NaN       NaN       NaN       NaN
# 1/3/20      0.000341 -0.007834 -0.010183 -0.013260 -0.011421 -0.005231
# 1/6/20      0.018238  0.005726 -0.004321  0.001598  0.019398  0.026654
# 1/7/20      0.010043 -0.000959 -0.002893  0.002533 -0.009864 -0.001932
# 1/8/20     -0.007623  0.013438 -0.008705  0.016191  0.010386  0.007118
#
#                 GOOG      AMZN      AMGN       ADI  ...      TCOM      ULTA  \
# Unnamed: 0                                          ...
# 1/2/20           NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1/3/20     -0.004907 -0.012139 -0.006789 -0.017604  ... -0.021369 -0.017207
# 1/6/20      0.024657  0.014886  0.007674 -0.011749  ... -0.013543  0.003118
# 1/7/20     -0.000624  0.002092 -0.009405  0.022751  ...  0.045951  0.008528
# 1/8/20      0.007880 -0.007809  0.000756  0.009032  ... -0.012323  0.019400
#
#                 VRSN      VRSK      VRTX       WBA      WDAY       WDC  \
# Unnamed: 0
# 1/2/20           NaN       NaN       NaN       NaN       NaN       NaN
# 1/3/20      0.021095  0.009728 -0.006699  0.000000  0.005852 -0.015392
# 1/6/20      0.009259  0.002294  0.027755  0.008632  0.006234 -0.019192
# 1/7/20      0.002318  0.008369 -0.001071 -0.005035  0.020414  0.067698
# 1/8/20      0.004626  0.009208  0.032620 -0.058357  0.033304  0.014484
#
#                  XEL      XLNX
# Unnamed: 0
# 1/2/20           NaN       NaN
# 1/3/20      0.004809 -0.023020
# 1/6/20     -0.001436 -0.020844
# 1/7/20     -0.002077  0.022830
# 1/8/20     -0.000961 -0.002815
#
# [5 rows x 100 columns]

# %% [markdown]
# ## Part 2: Find the portfolio that minimizes the daily average $\beta$-CVaR using the 2019 data
